# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

# %%
from utils.simulate.simulate_plant import simulate_plant

# %%
simulate_plant('PermeateFlow')
# Out:
# 10
# ['PermeateFlow_lag_1', 'FeedFlow', 'Recovery', 'FeedConductivity_x_FeedFlow', 'PermeateFlow_lag_2', 'ConcentrateFlow_x_FeedFlow', 'FeedFlow_x_FeedTemperature', 'PermeateFlow_lag_3', 'FeedPressure', 'FeedPressure_lag_1']
# 等待初始12个数据点...
# 开始实时预测(最多处理1000个点)...
# 已处理 50/1000 个点 | 最新预测: 3.149, 实际值: 4.472
# 已处理 100/1000 个点 | 最新预测: 3.828, 实际值: 4.453 | 异常边界: [2.984, 4.150]
# 已处理 150/1000 个点 | 最新预测: 3.538, 实际值: 3.914 | 异常边界: [3.221, 4.099]
# ⚠️ 异常点检测! 时间点: 158, 预测值: -8.566, 边界: [3.047, 4.188]
#   主要贡献特征: FeedFlow (贡献度: 0.3360)
# ⚠️ 异常点检测! 时间点: 159, 预测值: -0.534, 边界: [3.021, 4.202]
#   主要贡献特征: FeedFlow (贡献度: 0.3134)
# ⚠️ 异常点检测! 时间点: 160, 预测值: 1.363, 边界: [2.987, 4.221]
#   主要贡献特征: FeedFlow (贡献度: 0.2725)
# ⚠️ 异常点检测! 时间点: 161, 预测值: 2.283, 边界: [2.977, 4.225]
#   主要贡献特征: FeedFlow (贡献度: 0.2516)
# ⚠️ 异常点检测! 时间点: 162, 预测值: 2.720, 边界: [2.967, 4.230]
#   主要贡献特征: FeedFlow (贡献度: 0.2452)
# ⚠️ 异常点检测! 时间点: 185, 预测值: -2.483, 边界: [3.136, 4.133]
#   主要贡献特征: FeedFlow (贡献度: 0.3328)
# ...

# %%
# simulate_plant('PermeateConductivity')
