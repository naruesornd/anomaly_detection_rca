# %%
import sys
import os

sys.path.append(os.path.abspath('../src'))

# %%
from model.model_training.model_training import model_training

# %%
model_training(target=['PermeateFlow'])
# Out:
# 训练 RandomForest...
# 训练 simple RandomForest...
# Scaler已保存到: ../data/model_data/scaler_x_PermeateFlow.pkl
# Scaler已保存到: ../data/model_data/scaler_y_PermeateFlow.pkl
# Epoch 1/100: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:02<00:00, 72.94it/s]
# Epoch [1/100]  Train Loss: 0.2497  Test Loss: 0.0531
# Epoch 2/100: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:03<00:00, 64.77it/s]
# Epoch [2/100]  Train Loss: 0.1448  Test Loss: 0.0496
# Epoch 3/100: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:02<00:00, 71.23it/s]
# Epoch [3/100]  Train Loss: 0.1010  Test Loss: 0.0505
# Epoch 4/100: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:02<00:00, 70.69it/s]
# Epoch [4/100]  Train Loss: 0.1095  Test Loss: 0.0451
# Epoch 5/100: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:03<00:00, 66.49it/s]
# ...
