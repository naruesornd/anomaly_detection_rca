# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))
from model.model_training.model_training import model_training
model_training(target=['PermeateConductivity'])
# Out:
# 训练 RandomForest...
# 训练 simple RandomForest...
# Scaler已保存到: ../data/model_data/scaler_x_PermeateConductivity.pkl
# Scaler已保存到: ../data/model_data/scaler_y_PermeateConductivity.pkl
# Epoch 1/100: 100%|██████████| 155/155 [00:04<00:00, 34.20it/s]
# Epoch [1/100]  Train Loss: 0.1424  Test Loss: 0.1596
# Epoch 2/100: 100%|██████████| 155/155 [00:03<00:00, 39.29it/s]
# Epoch [2/100]  Train Loss: 0.1187  Test Loss: 0.1791
# Epoch 3/100: 100%|██████████| 155/155 [00:03<00:00, 39.31it/s]
# Epoch [3/100]  Train Loss: 0.1324  Test Loss: 0.1728
# Epoch 4/100: 100%|██████████| 155/155 [00:03<00:00, 47.59it/s]
# Epoch [4/100]  Train Loss: 0.0812  Test Loss: 0.2191
# Epoch 5/100: 100%|██████████| 155/155 [00:03<00:00, 45.57it/s]
# Epoch [5/100]  Train Loss: 0.0705  Test Loss: 0.2939
# Epoch 6/100: 100%|██████████| 155/155 [00:03<00:00, 49.62it/s]
# Epoch [6/100]  Train Loss: 0.0522  Test Loss: 0.2234
# Early stopping at epoch 6
# R2 Score: -1.0072, MAE: 0.9569
