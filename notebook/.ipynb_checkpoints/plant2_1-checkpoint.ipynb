# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

# %%
from utils.simulate.simulate_plant import simulate_plant

# %%
simulate_plant('PermeateFlow')
# Out:
# 10
# 等待初始12个数据点...
# 开始实时预测(最多处理2000个点)...
# 已处理 50/2000 个点 | 最新预测: 3.684, 实际值: 4.064
# 已处理 100/2000 个点 | 最新预测: 3.882, 实际值: 4.688
# 已处理 150/2000 个点 | 最新预测: 3.409, 实际值: 3.858
# 已处理 200/2000 个点 | 最新预测: 3.840, 实际值: 4.540
# 已处理 250/2000 个点 | 最新预测: 3.707, 实际值: 4.400
# 已处理 300/2000 个点 | 最新预测: 3.501, 实际值: 3.901
# 已处理 350/2000 个点 | 最新预测: 3.729, 实际值: 4.178
# 已处理 400/2000 个点 | 最新预测: 3.844, 实际值: 4.552
# 已处理 450/2000 个点 | 最新预测: 3.478, 实际值: -0.908
# 已处理 500/2000 个点 | 最新预测: 3.600, 实际值: 4.098
# 已处理 550/2000 个点 | 最新预测: 3.772, 实际值: 4.392
# 已处理 600/2000 个点 | 最新预测: 3.641, 实际值: 4.073
# 已处理 650/2000 个点 | 最新预测: 2.108, 实际值: 4.451
# 已处理 700/2000 个点 | 最新预测: 4.037, 实际值: 4.866
# 已处理 750/2000 个点 | 最新预测: 3.647, 实际值: 3.963
# 已处理 800/2000 个点 | 最新预测: 3.721, 实际值: 4.239
# 已处理 850/2000 个点 | 最新预测: 3.406, 实际值: -0.946
# 已处理 900/2000 个点 | 最新预测: 4.058, 实际值: 4.892
# 已处理 950/2000 个点 | 最新预测: 3.795, 实际值: 4.420
# 已处理 1000/2000 个点 | 最新预测: 4.150, 实际值: 4.900
# 已处理 1050/2000 个点 | 最新预测: 3.872, 实际值: 4.487
# 已处理 1100/2000 个点 | 最新预测: 3.718, 实际值: 4.265
# 已处理 1150/2000 个点 | 最新预测: 2.689, 实际值: 4.456
# 已处理 1200/2000 个点 | 最新预测: 3.646, 实际值: 4.091
# 已处理 1250/2000 个点 | 最新预测: 3.417, 实际值: 3.993
# 已处理 1300/2000 个点 | 最新预测: 3.636, 实际值: 4.174
# 已处理 1350/2000 个点 | 最新预测: 3.453, 实际值: 4.000
# 已处理 1400/2000 个点 | 最新预测: 3.983, 实际值: 4.536
# 已处理 1450/2000 个点 | 最新预测: 3.883, 实际值: 4.511
# 已处理 1500/2000 个点 | 最新预测: 3.810, 实际值: 4.479
# 已处理 1550/2000 个点 | 最新预测: 3.632, 实际值: 4.200
# 已处理 1600/2000 个点 | 最新预测: 3.795, 实际值: 4.332
# 已处理 1650/2000 个点 | 最新预测: 3.653, 实际值: 4.124
# 已处理 1700/2000 个点 | 最新预测: 3.874, 实际值: 4.402
# 已处理 1750/2000 个点 | 最新预测: 3.660, 实际值: 4.237
# 已处理 1800/2000 个点 | 最新预测: 3.430, 实际值: 3.857
# 已处理 1850/2000 个点 | 最新预测: 0.444, 实际值: 1.766
# 已处理 1900/2000 个点 | 最新预测: 3.674, 实际值: 4.247
# 已处理 1950/2000 个点 | 最新预测: 3.490, 实际值: 3.960
# 已处理 2000/2000 个点 | 最新预测: 3.578, 实际值: 4.061
# 预测结果已保存至 ../data/model_data/predictions_PermeateFlow.csv
# 结果图表已保存至 ../data/model_data/predictions_PermeateFlow.png

# %%
# simulate_plant('PermeateConductivity')
