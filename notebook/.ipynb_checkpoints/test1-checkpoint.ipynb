# %%
import sys
import os

sys.path.append(os.path.abspath('../src'))

# %%
from data_processor import DataProcessor
file_path = "../data/raw/data_factory_1.xlsx"
dp = DataProcessor(file_path)
dp.change_pivot('timestamp','param_name','value')
dp.drop_NA_with_feature(features=['FeedFlow','FeedTemperature'])
dp.rename_column_to_timestamp('timestamp')

# %%
from data_processor import CycleProcessor
cp = CycleProcessor(column_name='FeedFlow', df = dp.df, threshold=10)

# %%
cp.identify_cycles()
cp.assign_cycle_features()
# Out:
# param_name           timestamp  ConcentrateFlow  ConcentratePressure  \
# 0          2022-11-01 00:00:00       119.058464           254.427083
# 1          2022-11-01 01:00:00       119.284861           254.408333
# 2          2022-11-01 02:00:00       118.848508           254.044583
# 3          2022-11-01 03:00:00       118.631324           253.052917
# 4          2022-11-01 04:00:00       118.826094           254.352500
# ...                        ...              ...                  ...
# 16558      2024-10-31 19:00:00       125.494205           256.768333
# 16559      2024-10-31 20:00:00       125.228209           255.743750
# 16560      2024-10-31 21:00:00       125.290890           256.068333
# 16561      2024-10-31 22:00:00       125.739584           256.557083
# 16562      2024-10-31 23:00:00       125.587845           256.820455
#
# param_name  DifferentialPressure  FeedConductivity    FeedFlow  FeedPressure  \
# 0                      59.811424        238.884183  387.863646    273.325000
# 1                      59.793070        239.050850  388.577708    273.159583
# 2                      59.789896        239.117517  386.958541    272.952917
# 3                      59.742965        239.234183  388.434167    271.841667
# 4                      59.799096        239.217517  387.695000    273.296667
# ...                          ...               ...         ...           ...
# 16558                  58.073313        294.468367  425.652395    274.579583
# 16559                  57.892086        294.501700  424.630415    273.390417
# 16560                  57.863168        294.535033  424.934480    273.846667
# 16561                  57.940895        294.701700  426.029222    274.174167
# 16562                  57.907232        294.792609  425.455400    274.650000
#
# param_name  FeedTemperature  Permeate Pressure  PermeateConductivity  \
# 0                 83.620000          33.441771              2.684261
# 1                 83.740000          33.405078              2.690898
# 2                 83.768333          33.316614              2.695333
# 3                 84.445000          33.036159              2.644088
# 4                 84.073333          33.177526              2.674923
# ...                     ...                ...                   ...
# 16558             82.377917          33.324270             20.424674
# 16559             82.037500          33.009817             20.466732
# 16560             81.451667          33.089192             20.438021
# 16561             81.792500          33.801588             20.491976
# 16562             82.197727          33.957244             20.465802
#
# param_name  PermeateFlow   Recovery  cycle_id  cycle_time
# 0             269.623333  69.427135        -1          -1
# 1             270.177500  69.401548        -1          -1
# 2             269.188750  69.404638        -1          -1
# 3             270.778750  69.566374        -1          -1
# 4             269.938333  69.423221        -1          -1
# ...                  ...        ...       ...         ...
# 16558         300.128125  70.494039        -1          -1
# 16559         299.301458  70.492748        -1          -1
# 16560         299.532500  70.492430        -1          -1
# 16561         300.106458  70.415544        -1          -1
# 16562         299.990000  70.496302        -1          -1
#
# [16171 rows x 14 columns]

# %%
# file_path = '../data/cycle_processing_data/factory1.csv'
# cp.export_files(file_path)

# %%
# from utils.plot.plot_by_cycle import interactive_cycle_plot,plot_by_cycle
# interactive_cycle_plot(cp.df, plot_by_cycle)

# %%
# from utils.plot.plot_by_time_period import PlotByTimePeriod

# pbt = PlotByTimePeriod(cp.df)
# month = ['2022-11', '2022-12','2023-01']
# pbt.plot_by_month(month,'FeedFlow')

# %%
# from utils.IQR import iqr
# features = dp.list_columns()
# features = [f for f in features if f not in ['timestamp']]
# iqr(dp.df, features)

# %%
from feature_engineering import FeatureEngineering
fe = FeatureEngineering(dp)

# %%
fe.generate_cross_features(drop_features=['Recovery', 'PermeateFlow', 'PermeateConductivity', 'Permeate Pressure'])
fe.lag_engineer()

# %%
# from model.coarse_feature_selection.cfs import random_forest_regressor

# %%
dp.df = fe.df
features =dp.df.columns.tolist()

# %%
# fs = [f for f in features if f != ''and 'timestamp' not in f and 'PermeateFlow' not in f and 'PermeateConductivity' not in f and f not in ['Permeate Pressure'] ]
# #and'Permeate' not in f 
# print(fs)

# %%
# top_k_features = random_forest_regressor(dp, 'Permeate Pressure', fs)

# %%
import pandas as pd
import numpy as np

# %%
top_k_features = pd.read_csv("../data/temp_data/top_k_features.csv")
top_k_features
# Out:
#    Unnamed: 0                                   0
# 0           0             Permeate Pressure_lag_1
# 1           1             Permeate Pressure_lag_6
# 2           2             Permeate Pressure_lag_2
# 3           3             Permeate Pressure_lag_3
# 4           4                     FeedTemperature
# 5           5            Permeate Pressure_lag_12
# 6           6               FeedTemperature_lag_2
# 7           7  FeedConductivity_x_FeedTemperature
# 8           8                        FeedPressure
# 9           9               FeedTemperature_lag_1

# %%
top_k_features = top_k_features.iloc[:,1].tolist()
top_k_features
# Out:
# ['Permeate Pressure_lag_1',
#  'Permeate Pressure_lag_6',
#  'Permeate Pressure_lag_2',
#  'Permeate Pressure_lag_3',
#  'FeedTemperature',
#  'Permeate Pressure_lag_12',
#  'FeedTemperature_lag_2',
#  'FeedConductivity_x_FeedTemperature',
#  'FeedPressure',
#  'FeedTemperature_lag_1']

# %%
target = ['Permeate Pressure']

# %%
from model.fine_feature_selection.ffs import fine_feature_selection
s_features = fine_feature_selection(dp, top_k_features, target)
# Out:
# Epoch 1/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 251.00it/s]
# Epoch [1/30]  Train Loss: 0.7513  Test Loss: 0.1814
# Epoch 2/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 248.51it/s]
# Epoch [2/30]  Train Loss: 0.6619  Test Loss: 0.1813
# Epoch 3/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 243.91it/s]
# Epoch [3/30]  Train Loss: 0.6068  Test Loss: 0.1645
# Epoch 4/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 239.72it/s]
# Epoch [4/30]  Train Loss: 0.5626  Test Loss: 0.1451
# Epoch 5/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 248.19it/s]
# Epoch [5/30]  Train Loss: 0.5064  Test Loss: 0.1397
# Epoch 6/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 233.55it/s]
# Epoch [6/30]  Train Loss: 0.4681  Test Loss: 0.1423
# 🛑 No improvement for 1 epoch(s)
# Epoch 7/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 247.37it/s]
# Epoch [7/30]  Train Loss: 0.4456  Test Loss: 0.1434
# 🛑 No improvement for 2 epoch(s)
# Epoch 8/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 257.74it/s]
# Epoch [8/30]  Train Loss: 0.4336  Test Loss: 0.1472
# 🛑 No improvement for 3 epoch(s)
# Epoch 9/30: 100%|███████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 256.75it/s]
# Epoch [9/30]  Train Loss: 0.3940  Test Loss: 0.1483
# 🛑 No improvement for 4 epoch(s)
# Epoch 10/30: 100%|██████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 265.06it/s]
# Epoch [10/30]  Train Loss: 0.3774  Test Loss: 0.1526
# 🛑 No improvement for 5 epoch(s)
# Epoch 11/30: 100%|██████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 265.22it/s]
# Epoch [11/30]  Train Loss: 0.3737  Test Loss: 0.1536
# 🛑 No improvement for 6 epoch(s)
# Epoch 12/30: 100%|██████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 267.95it/s]
# Epoch [12/30]  Train Loss: 0.3597  Test Loss: 0.1494
# 🛑 No improvement for 7 epoch(s)
# Epoch 13/30: 100%|██████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 265.05it/s]
# Epoch [13/30]  Train Loss: 0.3548  Test Loss: 0.1514
# 🛑 No improvement for 8 epoch(s)
# Epoch 14/30: 100%|██████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 261.14it/s]
# Epoch [14/30]  Train Loss: 0.3480  Test Loss: 0.1504
# 🛑 No improvement for 9 epoch(s)
# Epoch 15/30: 100%|██████████████████████████████████████████████████████████████████| 202/202 [00:00<00:00, 268.01it/s]
# Epoch [15/30]  Train Loss: 0.3280  Test Loss: 0.1556
# 🛑 No improvement for 10 epoch(s)
#
# ✅ Early stopping triggered at epoch 15. Best val loss: 0.1397
# (3221, 1) (3221, 1)
# [Drop Feature Selection]
#
# Base Loss: 0.155617
# Drop Permeate Pressure_lag_1: loss delta = 1.275053
# Drop Permeate Pressure_lag_6: loss delta = 0.177399
# Drop Permeate Pressure_lag_2: loss delta = 0.005492
# Drop Permeate Pressure_lag_3: loss delta = 0.014206
# Drop FeedTemperature: loss delta = 0.584604
# Drop Permeate Pressure_lag_12: loss delta = 0.127197
# Drop FeedTemperature_lag_2: loss delta = 0.059528
# Drop FeedConductivity_x_FeedTemperature: loss delta = 0.034393
# Drop FeedPressure: loss delta = 0.017472
# Drop FeedTemperature_lag_1: loss delta = 0.016541
#
# 最终选定特征数: 9

# %%
from model.lstm_model.enhanced_lstm import lstm_model

# %%
lstm_model(dp, top_k_features, target)
# Out:
# Epoch 1/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 70.83it/s]
# Epoch [1/100]  Train Loss: 0.1489  Test Loss: 0.2287
# Epoch 2/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 74.43it/s]
# Epoch [2/100]  Train Loss: 0.1046  Test Loss: 0.1924
# Epoch 3/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 74.96it/s]
# Epoch [3/100]  Train Loss: 0.1018  Test Loss: 0.1823
# Epoch 4/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 74.17it/s]
# Epoch [4/100]  Train Loss: 0.1002  Test Loss: 0.1797
# Epoch 5/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 68.11it/s]
# Epoch [5/100]  Train Loss: 0.0995  Test Loss: 0.1789
# Epoch 6/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 74.85it/s]
# Epoch [6/100]  Train Loss: 0.0986  Test Loss: 0.1786
# Epoch 7/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 75.53it/s]
# Epoch [7/100]  Train Loss: 0.0977  Test Loss: 0.1780
# Epoch 8/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 69.41it/s]
# Epoch [8/100]  Train Loss: 0.0965  Test Loss: 0.1767
# Epoch 9/100: 100%|███████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 67.15it/s]
# Epoch [9/100]  Train Loss: 0.0949  Test Loss: 0.1704
# Epoch 10/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 62.13it/s]
# Epoch [10/100]  Train Loss: 0.0929  Test Loss: 0.1669
# Epoch 11/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 64.28it/s]
# Epoch [11/100]  Train Loss: 0.0960  Test Loss: 0.1135
# Epoch 12/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 66.40it/s]
# Epoch [12/100]  Train Loss: 0.1050  Test Loss: 0.1704
# Epoch 13/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 74.80it/s]
# Epoch [13/100]  Train Loss: 0.0831  Test Loss: 0.0949
# Epoch 14/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 74.71it/s]
# Epoch [14/100]  Train Loss: 0.0709  Test Loss: 0.0937
# Epoch 15/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 66.18it/s]
# Epoch [15/100]  Train Loss: 0.0670  Test Loss: 0.0851
# Epoch 16/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 64.97it/s]
# Epoch [16/100]  Train Loss: 0.0648  Test Loss: 0.0964
# Epoch 17/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 67.56it/s]
# Epoch [17/100]  Train Loss: 0.0648  Test Loss: 0.0806
# Epoch 18/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 67.63it/s]
# Epoch [18/100]  Train Loss: 0.0617  Test Loss: 0.0824
# Epoch 19/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 69.60it/s]
# Epoch [19/100]  Train Loss: 0.0645  Test Loss: 0.0845
# Epoch 20/100: 100%|██████████████████████████████████████████████████████████████████| 162/162 [00:02<00:00, 68.98it/s]
# Epoch [20/100]  Train Loss: 0.0607  Test Loss: 0.0861
# Early stopping at epoch 20

# %%
print(cp.df)
# Out:
# param_name           timestamp  ConcentrateFlow  ConcentratePressure  \
# 0          2022-11-01 00:00:00       119.058464           254.427083
# 1          2022-11-01 01:00:00       119.284861           254.408333
# 2          2022-11-01 02:00:00       118.848508           254.044583
# 3          2022-11-01 03:00:00       118.631324           253.052917
# 4          2022-11-01 04:00:00       118.826094           254.352500
# ...                        ...              ...                  ...
# 16558      2024-10-31 19:00:00       125.494205           256.768333
# 16559      2024-10-31 20:00:00       125.228209           255.743750
# 16560      2024-10-31 21:00:00       125.290890           256.068333
# 16561      2024-10-31 22:00:00       125.739584           256.557083
# 16562      2024-10-31 23:00:00       125.587845           256.820455
#
# param_name  DifferentialPressure  FeedConductivity    FeedFlow  FeedPressure  \
# 0                      59.811424        238.884183  387.863646    273.325000
# 1                      59.793070        239.050850  388.577708    273.159583
# 2                      59.789896        239.117517  386.958541    272.952917
# 3                      59.742965        239.234183  388.434167    271.841667
# 4                      59.799096        239.217517  387.695000    273.296667
# ...                          ...               ...         ...           ...
# 16558                  58.073313        294.468367  425.652395    274.579583
# 16559                  57.892086        294.501700  424.630415    273.390417
# 16560                  57.863168        294.535033  424.934480    273.846667
# 16561                  57.940895        294.701700  426.029222    274.174167
# 16562                  57.907232        294.792609  425.455400    274.650000
#
# param_name  FeedTemperature  Permeate Pressure  PermeateConductivity  \
# 0                 83.620000          33.441771              2.684261
# 1                 83.740000          33.405078              2.690898
# 2                 83.768333          33.316614              2.695333
# 3                 84.445000          33.036159              2.644088
# 4                 84.073333          33.177526              2.674923
# ...                     ...                ...                   ...
# 16558             82.377917          33.324270             20.424674
# 16559             82.037500          33.009817             20.466732
# 16560             81.451667          33.089192             20.438021
# 16561             81.792500          33.801588             20.491976
# 16562             82.197727          33.957244             20.465802
#
# param_name  PermeateFlow   Recovery  cycle_id  cycle_time
# 0             269.623333  69.427135        -1          -1
# 1             270.177500  69.401548        -1          -1
# 2             269.188750  69.404638        -1          -1
# 3             270.778750  69.566374        -1          -1
# 4             269.938333  69.423221        -1          -1
# ...                  ...        ...       ...         ...
# 16558         300.128125  70.494039        -1          -1
# 16559         299.301458  70.492748        -1          -1
# 16560         299.532500  70.492430        -1          -1
# 16561         300.106458  70.415544        -1          -1
# 16562         299.990000  70.496302        -1          -1
#
# [16171 rows x 14 columns]

# %%
from model.lstm_model.enhanced_lstm import model_analysis

# %%
model_analysis()
